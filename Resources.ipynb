# %% [markdown]
# # AI & Machine Learning Resources

# %% [markdown]
# ## Programming Learning Resources
# * **freeCodeCamp** - https://www.freecodecamp.org/
# * **Coursera** - https://www.coursera.org/
# * **edX** - https://www.edx.org/
# * **codecademy** - https://www.codecademy.com/
# * **Udacity** - https://www.udacity.com/
# * **Udemy** - https://www.udemy.com/

# %% [markdown]
# ## Machine Learning and Data Science Learning Resources
# * **Coursera** - https://www.coursera.org/
# * **edX** - https://www.edx.org/
# * **Udacity** - https://www.udacity.com/
# * **Udemy** - https://www.udemy.com/

# %% [markdown]
# ## Specific Course Recommendations
# * **AI for Everyone | Coursera** - https://www.coursera.org/learn/ai-for-everyone
# * **Complete Machine Learning & Data Science Bootcamp 2021 | Udemy** - https://www.udemy.com/course/complete-machine-learning-and-data-science-zero-to-mastery/   (Note:  `High ROI Option`.  Includes Python programming, AI/ML concepts, ML programming, and Deep Learning)
# * **AI Fundamentals | Udacity** - https://www.udacity.com/course/ai-fundamentals--ud099
# * **IBM Data Science Professional Certificate | Coursera** - https://www.coursera.org/professional-certificates/ibm-data-science
# * **TensorFlow Developer Certificate in 2021:  Zero to Mastery | Udemy** - https://www.udemy.com/course/tensorflow-developer-certificate-machine-learning-zero-to-mastery/  (Note: Recommend the Complete Machine Learning  Data Science course be completed first).
# * **Deep Learning Specialization | Coursera** - https://www.coursera.org/specializations/deep-learning

# %% [markdown]
# ## AI / ML / DS Podcasts
# * **This Week in Machine Learning** - https://twimlai.com/
# * **Machine Learning Guide** - https://ocdevel.com/mlg
# * **Data Science Impostors** - https://datascienceimposters.com/
# * **AI in Business** - https://emerj.com/artificial-intelligence-podcast/
# * **AI in Financial Services** - https://emerj.com/ai-in-financial-services-podcast/

# %% [markdown]
# ## YouTube Channels
# * **DeepLearningAI** - https://www.youtube.com/c/Deeplearningai
# * **Ai4** - https://www.youtube.com/c/Ai4conferences
# * **Facebook AI** - https://www.youtube.com/c/FacebookAI
# * **Daniel Bourke** - https://www.youtube.com/channel/UCr8O8l5cCX85Oem1d18EezQ
# * **TensorFlow** - https://www.youtube.com/c/TensorFlow
# * **Machine Learning Conference** - https://www.youtube.com/channel/UCWoVlB63O0951q0j4Vkheiw
# * **Standford Human Centered AI** - https://www.youtube.com/channel/UChugFTK0KyrES9terTid8vA

# %% [markdown]
# ## Other Goodies
# * **Scikit-Learn Documentation** - https://scikit-learn.org/stable/
# * **Neural Network Playground** - https://playground.tensorflow.org/
# * **Convolutional Neural Network (CNN) Explainer** - https://poloclub.github.io/cnn-explainer/

# %% [markdown]
# ### Scikit-Learn Algorithm Cheat Sheet
# ![image.png](attachment:image.png)
#
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
